# %% [markdown]
# # Sistemas de EDOs -  Aula 29/09

# %%
import numpy as np
import csv
import pandas as pd

# %%
#Derivada
def f(x,y): 
    df1 = -(8/5)*y[0] + (3/10)*y[1]
    df2 = (8/5)*y[0] - (4/5)*y[1]
    return df1, df2

# %% [markdown]
# ## Euler

# %%
def euler(f, x, y0, h):
    y = np.zeros((len(x), len(y0)))
    f1 = np.zeros((len(x), len(y0)))
    y[0] = y0

    for i in np.arange(0, len(x)-1):
        f1[i] = f(x[i], y[i])
        y[i+1] = y[i] + f1[i] * h
                
    return y

# %%
#domínios
a  = 0.0
b  = 10
y0 = [0,12]  #PVI confição inicial
h  = 0.1  #intervalo (delta) h=(b-a)/100

# %%
h  = 0.1

# %%
x = np.arange(a, b, h) #ou t
len(x)
# Out:
# 100

# %%
E = euler(f, x, y0, h)
print (f'Solução Euler: {E}')
# len(E)
# Out:
# Solução Euler: [[ 0.         12.        ]
#  [ 0.36       11.04      ]
#  [ 0.6336     10.2144    ]
#  [ 0.838656    9.498624  ]
#  [ 0.98942976  8.87291904]
#  [ 1.09730857  8.32139428]
#  [ 1.17138103  7.83125211]
#  [ 1.21889763  7.3921729 ]
#  [ 1.24563919  6.99582269]
#  [ 1.2562116   6.63545915]
#  [ 1.25428152  6.30561627]
#  [ 1.24276497  6.00185201]
#  [ 1.22397813  5.72054625]
#  [ 1.19975802  5.45873905]
#  [ 1.17155891  5.21400121]
#  [ 1.14052952  4.98433054]
#  [ 1.10757471  4.76806882]
#  [ 1.07340482  4.56383526]
#  [ 1.03857511  4.37047321]
#  [ 1.00351729  4.18700737]
#  [ 0.96856474  4.01260955]
#  [ 0.93397267  3.84657114]
#  [ 0.89993418  3.68828108]
#  [ 0.86659314  3.53720806]
#  [ 0.83405448  3.39288632]
#  [ 0.80239235  3.25490413]
#  [ 0.7716567   3.12289458]
#  [ 0.74187847  2.99652808]
#  [ 0.71307375  2.87550639]
#  [ 0.68524714  2.75955768]
#  [ 0.65839433  2.64843261]
#  [ 0.63250422  2.54190109]
#  [ 0.60756058  2.43974968]
#  [ 0.58354337  2.3417794 ]
#  [ 0.56042982  2.24780399]
#  [ 0.53819516  2.15764844]
#  [ 0.51681339  2.07114779]
#  [ 0.49625768  1.98814611]
#  [ 0.47650084  1.90849565]
#  [ 0.45751557  1.83205613]
#  [ 0.43927476  1.75869413]
#  [ 0.42175163  1.68828256]
#  [ 0.40491984  1.62070022]
#  [ 0.38875367  1.55583138]
#  [ 0.37322803  1.49356545]
#  [ 0.35831851  1.4337967 ]
#  [ 0.34400145  1.37642393]
#  [ 0.33025393  1.32135024]
#  [ 0.31705381  1.26848285]
#  [ 0.30437969  1.21773284]
#  [ 0.29221092  1.16901496]
#  [ 0.28052762  1.12224751]
#  [ 0.26931063  1.07735213]
#  [ 0.25854149  1.03425366]
#  [ 0.24820246  0.99288001]
#  [ 0.23827647  0.953162  ]
#  [ 0.22874709  0.91503327]
#  [ 0.21959856  0.87843015]
#  [ 0.21081569  0.8432915 ]
#  [ 0.20238393  0.8095587 ]
#  [ 0.19428926  0.77717543]
#  [ 0.18651824  0.74608768]
#  [ 0.17905795  0.71624358]
#  [ 0.17189599  0.68759337]
#  [ 0.16502043  0.66008925]
#  [ 0.15841984  0.63368538]
#  [ 0.15208323  0.60833773]
#  [ 0.14600004  0.58400402]
#  [ 0.14016016  0.56064371]
#  [ 0.13455384  0.53821784]
#  [ 0.12917176  0.51668903]
#  [ 0.12400495  0.49602139]
#  [ 0.1190448   0.47618047]
#  [ 0.11428305  0.4571332 ]
#  [ 0.10971176  0.43884783]
#  [ 0.10532331  0.42129388]
#  [ 0.1011104   0.4044421 ]
#  [ 0.097066    0.3882644 ]
#  [ 0.09318337  0.37273381]
#  [ 0.08945604  0.35782444]
#  [ 0.08587781  0.34351145]
#  [ 0.0824427   0.32977099]
#  [ 0.079145    0.31658014]
#  [ 0.0759792   0.30391693]
#  [ 0.07294004  0.29176025]
#  [ 0.07002244  0.28008983]
#  [ 0.06722155  0.26888624]
#  [ 0.06453269  0.25813079]
#  [ 0.06195138  0.24780555]
#  [ 0.05947333  0.23789333]
#  [ 0.05709439  0.22837759]
#  [ 0.05481062  0.21924249]
#  [ 0.05261819  0.21047279]
#  [ 0.05051347  0.20205388]
#  [ 0.04849293  0.19397172]
#  [ 0.04655321  0.18621285]
#  [ 0.04469108  0.17876434]
#  [ 0.04290344  0.17161376]
#  [ 0.0411873   0.16474921]
#  [ 0.03953981  0.15815924]]

# %%
# d = E[0]
# c = E[1]

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(font_scale = 1, font='sans serif')
plt.figure(figsize=(10,6), facecolor = "#FFF")

plt.figure(1)
plt.rcParams.update({'font.size': 10})
# plt.plot(x, F, 'r--', linewidth = 1, label = 'Range Kutta')
# plt.plot(x, , 'b--', linewidth = 1, label = "Analítica")
plt.plot(x, E, 'r', linewidth = 1, label = "Euler")
plt.title('Sistema EDOs')
plt.xlabel('x')
plt.ylabel('y(x)')
plt.legend(['Euler'])
plt.grid(True)
plt.show()

# %% [markdown]
# # Range Kutta

# %%
def range_kutta(f, x, y0, h):
    y = np.zeros((len(x), len(y0)))
    k1 = np.zeros((len(x), len(y0)))
    k2 = np.zeros((len(x), len(y0)))
    k3 = np.zeros((len(x), len(y0)))
    k4 = np.zeros((len(x), len(y0)))
    y[0] = y0
    
    for i in np.arange(0, len(x)-1):
                  
        k1[i] = f(x[i],y[i])
        k2[i] = f(x[i] + (h/2), y[i] + (h/2) * k1[i])
        k3[i] = f(x[i] + h, y[i] + h * k2[i])
        k4[i] = f(x[i] + h, y[i] + h * k3[i])
            
        y[i+1] = y[i] + (h/6) * (k1[i] + 2 * k2[i] + 2 * k3[i] + k4[i])

                
    return y

# %%
R = range_kutta(f, x, y0, h)
print (f'Solução Range Kutta: {R}')
# Out:
# Solução Range Kutta: [[ 0.         12.        ]
#  [ 0.30805248 11.12180992]
#  [ 0.54992878 10.35006414]
#  [ 0.73773454  9.66791247]
#  [ 0.88142821  9.06139527]
#  [ 0.98919938  8.51893794]
#  [ 1.06778055  8.03093418]
#  [ 1.12270403  7.58940248]
#  [ 1.15851364  7.18770288]
#  [ 1.17893918  6.82030343]
#  [ 1.18704015  6.4825877 ]
#  [ 1.1853242   6.17069598]
#  [ 1.17584471  5.88139434]
#  [ 1.1602812   5.61196666]
#  [ 1.1400056   5.36012554]
#  [ 1.11613679  5.12393881]
#  [ 1.08958556  4.90176888]
#  [ 1.06109168  4.69222272]
#  [ 1.03125436  4.49411051]
#  [ 1.00055741  4.30641155]
#  [ 0.96938991  4.12824609]
#  [ 0.93806324  3.95885201]
#  [ 0.90682511  3.79756561]
#        0.55746033, 0.53609839, 0.5155064 , 0.4956653 , 0.47655487,
#        0.45815406, 0.44044136, 0.423395  , 0.40699319, 0.39121425,
#        0.37603673, 0.36143953, 0.34740198, 0.33390384, 0.3209254 ,
#        0.30844751, 0.29645153, 0.28491944, 0.27383376, 0.26317759,
#        0.25293461, 0.24308907, 0.23362576, 0.22453001, 0.2157877 ,
#        0.20738522, 0.19930945, 0.19154777, 0.18408804, 0.17691856,
#        0.17002809, 0.16340581, 0.15704131, 0.15092457, 0.14504599,
#        0.13939629, 0.13396659, 0.12874833, 0.12373329, 0.11891355,
#        0.11428153, 0.10982991, 0.10555167, 0.10144007, 0.09748861,
#        0.09369107, 0.09004144, 0.08653397, 0.08316313, 0.07992359,
#        0.07681024, 0.07381816, 0.07094263, 0.06817911, 0.06552325,
#        0.06297083, 0.06051785, 0.05816042, 0.05589481, 0.05371747,
#        0.05162494, 0.04961392, 0.04768124, 0.04582384, 0.0440388 ])

# %%
df2 = R[:,1]
df2
# Out:
# array([12.        , 11.12180992, 10.35006414,  9.66791247,  9.06139527,
#         8.51893794,  8.03093418,  7.58940248,  7.18770288,  6.82030343,
#         6.4825877 ,  6.17069598,  5.88139434,  5.61196666,  5.36012554,
#         5.12393881,  4.90176888,  4.69222272,  4.49411051,  4.30641155,
#         4.12824609,  3.95885201,  3.79756561,  3.64380567,  3.49706029,
#         3.35687597,  3.22284858,  3.09461585,  2.97185116,  2.85425836,
#         2.74156744,  2.63353099,  2.52992115,  2.43052713,  2.33515308,
#         2.24361636,  2.15574602,  2.07138154,  1.99037176,  1.912574  ,
#         1.83785323,  1.76608141,  1.69713694,  1.63090416,  1.56727284,
#         1.50613789,  1.44739897,  1.39096017,  1.33672979,  1.28462007,
#         1.23454696,  1.18642995,  1.14019187,  1.09575872,  1.05305953,
#         1.01202622,  0.97259345,  0.93469848,  0.89828112,  0.86328356,
#         0.82965028,  0.79732796,  0.7662654 ,  0.73641341,  0.70772473,
#         0.68015397,  0.65365752,  0.62819348,  0.60372158,  0.58020314,
#         0.55760098,  0.5358794 ,  0.51500406,  0.494942  ,  0.4756615 ,
#         0.45713211,  0.43932458,  0.42221076,  0.40576363,  0.38995721,
#         0.37476655,  0.36016764,  0.34613745,  0.3326538 ,  0.31969541,
#         0.30724181,  0.29527335,  0.28377111,  0.27271694,  0.26209338,
#         0.25188367,  0.24207166,  0.23264189,  0.22357944,  0.21487002,
#         0.20649987,  0.19845578,  0.19072504,  0.18329544,  0.17615527])

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(font_scale = 1, font='sans serif')
plt.figure(figsize=(10,6), facecolor = "#FFF")

plt.figure(1)
plt.rcParams.update({'font.size': 10})
# plt.plot(x, E, 'r', linewidth = 1, label = "Euler")
plt.plot(x, R[:,0], 'b--', linewidth = 1, label = 'Range Kutta df1')
plt.plot(x, R[:,1], 'g--', linewidth = 1, label = 'Range Kutta df2')
# plt.plot(x, df2, 'r--', linewidth = 1, label = 'Range Kutta')
plt.plot(x, E[:,0], 'r--', linewidth = 1, label = 'Euler df1')
plt.plot(x, E[:,1], 'y', linewidth = 1, label = 'Euler df2')

plt.title('Sistema EDOs - Euler vs Range Kutta')
plt.xlabel('x')
plt.ylabel('y(x)')
plt.legend()
plt.grid(True)
plt.show()
