# %% [markdown]
# # Método de Adam-Bashfort (Aula 13/10)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
#Analítica
def analitf(t): 
    return (t+1.0)**2 - np.exp(t)/2.0

# %%
#Derivada
def f(tau, W): 
    return W - tau**2 + 1.0

# %% [markdown]
# ## Método de Adams-Bashforth - 2 passos

# %%
def euler_bashforth(x, y0, h):
    y = np.zeros(len(x))
    y[0] = y0

    K1 = f(x[0] , y[0])
    y [1] = y [0] +  h *(K1)

    for i in np.arange(1, len(x)-1):
        K2 = K1
        K1=f(x[i],y[i])
        y[i+1] = y[i] + h *(3* K1 - K2) /2
                
    return y

# %%
#domínios
a  = 0.0
b  = 2.0
y0 = 0.5  #PVI confição inicial
n  = 0   # Número de interações
h  = 0.001  #intervalo (delta) h=(b-a)/100
#h  = 0.1

# %%
x = np.arange(a, b, h) #ou t
len(x)
# Out:
# 200

# %%
F = euler_bashforth(x, y0, h)
print (f'Solução Euler: {F}')
len(F)
# Out:
# Solução Euler: [0.5        0.515      0.5302235  0.54559635 0.56111768 0.57678696
#  0.59260368 0.6085673  0.62467729 0.64093311 0.65733422 0.67388007
#  0.6905701  0.70740375 0.72438046 0.74149965 0.75876074 0.77616315
#  0.7937063  0.81138957 0.82921239 0.84717412 0.86527417 0.88351192
#  0.90188672 0.92039797 0.939045   0.95782719 0.97674387 0.99579439
#  1.01497809 1.03429429 1.05374231 1.07332147 1.09303109 1.11287044
#  1.13283885 1.15293558 1.17315992 1.19351114 1.2139885  1.23459128
#  1.2553187  1.27617003 1.29714448 1.3182413  1.3394597  1.36079889
#  1.38225807 1.40383645 1.4255332  1.44734752 1.46927857 1.49132551
#  1.5134875  1.53576368 1.5581532  1.58065518 1.60326874 1.625993
#  1.64882705 1.67176999 1.6948209  1.71797887 1.74124295 1.7646122
#  1.78808566 1.81166239 1.8353414  1.8591217  1.88300232 1.90698225
#  1.93106047 1.95523597 1.9795077  2.00387464 2.02833572 2.05288988
#  2.07753605 2.10227314 2.12710006 2.1520157  2.17701893 2.20210864
#  2.22728367 2.25254288 2.27788511 2.30330917 2.32881388 2.35439805
#  2.38006045 2.40579986 2.43161506 2.45750479 2.48346778 2.50950277
#  2.53560848 2.56178359 2.5880268  2.61433679 2.6407122  2.6671517
#  2.69365392 2.72021747 2.74684096 2.77352299 2.80026213 2.82705694
#  2.85390599 2.88080779 2.90776088 2.93476375 2.96181491 2.98891281
#  3.01605593 3.0432427  3.07047156 3.09774092 3.12504918 3.15239471
#  3.17977589 3.20719105 3.23463854 3.26211666 3.28962372 3.31715799
#  3.34471774 3.37230122 3.39990665 3.42753224 3.45517619 3.48283667
#  3.51051184 3.53819984 3.56589878 3.59360676 3.62132187 3.64904216
#  3.67676568 3.70449046 3.73221449 3.75993575 3.78765222 3.81536182
#  3.84306249 3.87075211 3.89842858 3.92608975 3.95373346 3.98135751
#  4.0089597  4.03653781 4.06408958 4.09161274 4.11910498 4.14656399
#  4.17398742 4.20137292 4.22871807 4.25602048 4.2832777  4.31048726
#  4.33764668 4.36475344 4.39180501 4.41879882 4.44573228 4.47260277
#  4.49940765 4.52614425 4.55280987 4.5794018  4.60591728 4.63235353
#  4.65870774 4.68497709 4.71115871 4.73724971 4.76324716 4.78914812
#  4.8149496  4.84064861 4.86624209 4.89172697 4.91710017 4.94235854
#  4.96749891 4.9925181  5.01741288 5.04217998 5.06681612 5.09131796
#  5.11568215 5.13990529 5.16398396 5.18791469 5.211694   5.23531833
#  5.25878414 5.28208781]
# 200

# %%
analic = analitf(x)
print (f'Solução Analítica: {analic}')
len(analic)
# Out:
# Solução Analítica: [0.5        0.51507492 0.53029933 0.54567273 0.56119461 0.57686445
#  0.59268173 0.60864591 0.62475647 0.64101286 0.65741454 0.67396096
#  0.69065157 0.70748581 0.7244631  0.74158288 0.75884456 0.77624757
#  0.79379132 0.8114752  0.82929862 0.84726097 0.86536163 0.8836
#  0.90197542 0.92048729 0.93913496 0.95791777 0.97683509 0.99588626
#  1.0150706  1.03438744 1.05383612 1.07341594 1.0931262  1.11296623
#  1.13293529 1.15303269 1.17325771 1.1936096  1.21408765 1.23469111
#  1.25541922 1.27627124 1.29724639 1.31834391 1.33956301 1.3609029
#  1.3823628  1.40394189 1.42563936 1.4474544  1.46938618 1.49143385
#  1.51359657 1.53587349 1.55826375 1.58076647 1.60338078 1.62610579
#  1.6489406  1.6718843  1.69493598 1.71809471 1.74135956 1.76472959
#  1.78820383 1.81178134 1.83546113 1.85924223 1.88312365 1.90710437
#  1.93118339 1.9553597  1.97963224 2.00399999 2.02846189 2.05301687
#  2.07766387 2.10240179 2.12722954 2.15214601 2.17715008 2.20224063
#  2.22741651 2.25267657 2.27801965 2.30344457 2.32895015 2.35453517
#  2.38019844 2.40593873 2.43175481 2.45764541 2.48360929 2.50964517
#  2.53575176 2.56192777 2.58817188 2.61448276 2.64085909 2.66729949
#  2.69380262 2.72036708 2.74699149 2.77367444 2.80041451 2.82721025
#  2.85406022 2.88096296 2.90791699 2.9349208  2.9619729  2.98907175
#  3.01621582 3.04340355 3.07063336 3.09790368 3.1252129  3.1525594
#  3.17994154 3.20735767 3.23480613 3.26228523 3.28979327 3.31732852
#  3.34488926 3.37247372 3.40008014 3.42770672 3.45535167 3.48301314
#  3.51068931 3.53837831 3.56607825 3.59378723 3.62150335 3.64922465
#  3.67694919 3.70467497 3.73240002 3.7601223  3.78783978 3.8155504
#  3.84325209 3.87094274 3.89862024 3.92628243 3.95392716 3.98155224
#  4.00915546 4.0367346  4.0642874  4.09181159 4.11930486 4.14676491
#  4.17418938 4.2015759  4.22892209 4.25622554 4.28348379 4.31069439
#  4.33785484 4.36496264 4.39201524 4.41901009 4.44594458 4.4728161
#  4.49962201 4.52635965 4.5530263  4.57961926 4.60613577 4.63257305
#  4.65892829 4.68519866 4.7113813  4.73747332 4.76347179 4.78937377
#  4.81517627 4.84087628 4.86647078 4.89195667 4.91733087 4.94259024
#  4.96773161 4.9927518  5.01764757 5.04241566 5.06705278 5.0915556
#  5.11592077 5.14014488 5.16422451 5.18815621 5.21193647 5.23556176
#  5.25902851 5.28233312]
# 200

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(font_scale = 1, font='sans serif')
plt.figure(figsize=(10,6), facecolor = "#FFF")

plt.figure(1)
plt.rcParams.update({'font.size': 10})
plt.plot(x, F, 'r--', linewidth = 1)
plt.plot(x, analic, 'b--', linewidth = 2)
plt.title('Euler')
plt.xlabel('x')
plt.ylabel('y(x)')
#plt.legen(['Euler'])
plt.grid(True)
plt.show()

# %% [markdown]
# # Adams-Bashforth 3 passos

# %%
def bashforth(x, y0, h):
    y = np.zeros(len(x))
    y[0] = y0
    
    K1 = f(x[1], y[1])
    K2 = f(x[0], y[0])
    y[1] = y[0] +  h *(K2)
    y[2] = y[1] +  h *(K1)
    
    for i in np.arange(2, len(x)-1):
        K3 = K2
        K2 = K1
        K1=f(x[i],y[i])
        y[i+1] = y[i] + h*(23* K1 -16* K2 + 5* K3 ) /12
                
    return y

# %%
E = bashforth(x, y0, h)
print (f'Solução Euler: {E}')
len(E)
# Out:
# Solução Euler: [0.5        0.5015     0.5025     ... 5.29822764 5.30053701 5.3028447 ]
# 2000

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(font_scale = 1, font='sans serif')
plt.figure(figsize=(10,6), facecolor = "#FFF")

plt.figure(1)
plt.rcParams.update({'font.size': 10})
# plt.plot(x, E, 'r', linewidth = 1, label = "Euler")
plt.plot(x, R[:,0], 'b--', linewidth = 1, label = 'Range Kutta df1')
plt.plot(x, R[:,1], 'g--', linewidth = 1, label = 'Range Kutta df2')
# plt.plot(x, df2, 'r--', linewidth = 1, label = 'Range Kutta')
plt.plot(x, E[:,0], 'r--', linewidth = 1, label = 'Euler df1')
plt.plot(x, E[:,1], 'y', linewidth = 1, label = 'Euler df2')

plt.title('Sistema EDOs - Euler vs Range Kutta')
plt.xlabel('x')
plt.ylabel('y(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
analic = analitf(x)
print (f'Solução Analítica: {analic}')
len(analic)
# Out:
# Solução Analítica: [0.5        0.50150075 0.503003   ... 5.29854793 5.30085762 5.30316563]
# 2000

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(font_scale = 1, font='sans serif')
plt.figure(figsize=(10,6), facecolor = "#FFF")

plt.figure(1)
plt.rcParams.update({'font.size': 10})
plt.plot(x, E, 'r--', linewidth = 2)
# plt.plot(x, F, 'b--', linewidth = 1)
plt.plot(x, analic, 'g--', linewidth = 1)

plt.title('Euler')
plt.xlabel('x')
plt.ylabel('y(x)')
#plt.legen(['Euler'])
plt.grid(True)
plt.show()

# %% [markdown]
# ## Range-Kutta - Método de Barshforth com 4 passos

# %%
def range_kutta(x, y0, h):
    y = np.zeros(len(x))
    y[0] = y0
    
    for i in np.arange(3, len(x)-1):
          
            k1 = f(x[i],y[i])
            k2 = f(x[i] + (h/2), y[i] + (h/2) * k1)
            k3 = f(x[i] + h, y[i] + h * k2)
            k4 = f(x[i] + h, y[i] + h * k3)
            
            y[i+1] = y[i] + (h/6) * (k1 + 2 * k2 + 2 * k3 + k4)
#             x[i+1] = x[i] + h
            print (y[i+1])
                
    return y

# %%
def rk4(f,x,y,h,n) :
    for _ in range (n):
        k1 = h * f (x, y)
        k2 = h * f ( x + 0.5* h , y + 0.5* k1 )
        k3 = h * f ( x + 0.5* h , y + 0.5* k2 )
        k4 = h * f ( x + h , y + k3 )
        y += (k1 + 2* k2 + 2* k3 + k4 ) / 6
        x += h
    return y

# %%
def adams(x, y0, h):
    _y = np.zeros(len(x))
    _y[0] = y0
    
    for i in np.arange (0 , 3) :
        _y[i+1] = rk4(f,x[i],_y[i],h,2)

    f_m2 = f(x[0] , y[0])
    f_m1 = f(x[1] , y[1])
    f_0 = f(x[2] , y[2])
    f_1 = f(x[3] , y[3])

    for i in range (3, len(x)- 1) : # Inicia no 3
        f_m3 = f_m2
        f_m2 = f_m1
        f_m1 = f_0
        f_0 = f_1

        _y[i+1] = _y[i]+(h/24) * (55* f_0 - 59* f_m1 + 37* f_m2 - 9* f_m3 )
        f_1 = f (x[i+1] , _y[i+1])

    return _y

# %%
R = adams(x, y0, h)
print (f'Solução Range Kutta: {R}')
len(R)
# Out:
# Solução Range Kutta: [0.5        0.503003   0.50601177 0.50902592 0.51002469 0.51219146
#  0.51310839 0.51480718 0.51631829 0.51782769 0.51933731 0.52084637
#  0.52235474 0.52386221 0.5253686  0.52687368 0.52837728 0.52987917
#  0.53137917 0.53287706 0.53437265 0.53586574 0.53735612 0.53884358
#  0.54032794 0.54180897 0.54328649 0.54476028 0.54623014 0.54769587
#  0.54915726 0.55061412 0.55206622 0.55351338 0.55495538 0.55639202
#  0.5578231  0.5592484  0.56066772 0.56208087 0.56348762 0.56488777
#  0.56628112 0.56766747 0.56904659 0.57041829 0.57178236 0.57313859
#  0.57448677 0.57582669 0.57715815 0.57848094 0.57979484 0.58109966
#  0.58239517 0.58368118 0.58495746 0.58622382 0.58748004 0.58872591
#  0.58996122 0.59118576 0.59239932 0.59360169 0.59479266 0.59597201
#  0.59713953 0.59829502 0.59943825 0.60056902 0.60168712 0.60279232
#  0.60388443 0.60496322 0.60602849 0.60708001 0.60811757 0.60914097
#  0.61014998 0.6111444  0.612124   0.61308858 0.61403791 0.61497178
#  0.61588998 0.61679229 0.61767849 0.61854837 0.61940172 0.6202383
#  0.62105792 0.62186035 0.62264537 0.62341277 0.62416232 0.62489382
#  0.62560704 0.62630176 0.62697777 0.62763484 0.62827276 0.62889131
#  0.62949027 0.63006942 0.63062854 0.6311674  0.6316858  0.6321835
#  0.63266029 0.63311595 0.63355025 0.63396298 0.6343539  0.63472281
#  0.63506947 0.63539368 0.63569519 0.63597379 0.63622926 0.63646138
#  0.63666991 0.63685464 0.63701534 0.6371518  0.63726377 0.63735105
#  0.6374134  0.6374506  0.63746243 0.63744865 0.63740905 0.63734339
#  0.63725146 0.63713302 0.63698785 0.63681572 0.63661641 0.63638968
#  0.63613531 0.63585307 0.63554274 0.63520408 0.63483687 0.63444088
#  0.63401588 0.63356163 0.63307792 0.63256451 0.63202118 0.63144768
#  0.63084379 0.63020929 0.62954394 0.6288475  0.62811975 0.62736046
#  0.6265694  0.62574632 0.62489101 0.62400323 0.62308274 0.62212932
#  0.62114272 0.62012272 0.61906909 0.61798158 0.61685998 0.61570403
#  0.61451351 0.61328818 0.6120278  0.61073215 0.60940099 0.60803408
#  0.60663118 0.60519206 0.60371648 0.60220421 0.60065501 0.59906864
#  0.59744487 0.59578346 0.59408416 0.59234674 0.59057097 0.58875661
#  0.58690341 0.58501113 0.58307955 0.58110841 0.57909749 0.57704653
#  0.5749553  0.57282356 0.57065107 0.56843758 0.56618286 0.56388667
#  0.56154875 0.55916888]
# 200

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(font_scale = 1, font='sans serif')
plt.figure(figsize=(10,6), facecolor = "#FFF")

plt.figure(1)
plt.rcParams.update({'font.size': 10})
plt.plot(x, R, 'r--', linewidth = 2)
# plt.plot(x, F, 'b--', linewidth = 1)
# plt.plot(x, analic, 'g--', linewidth = 1)

plt.title('Euler')
plt.xlabel('x')
plt.ylabel('y(x)')
#plt.legen(['Euler'])
plt.grid(True)
plt.show()
